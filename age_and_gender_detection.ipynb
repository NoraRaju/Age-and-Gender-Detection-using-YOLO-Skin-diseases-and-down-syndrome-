# %%
# Import necessary modules first.
import tensorflow as tf
from tensorflow.keras.utils import load_img
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, Input
import numpy as np
import random
import matplotlib.pyplot as plt
import os
import seaborn as sns
import warnings
from tqdm.notebook import tqdm
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
BASE_DIR = '/content/drive/MyDrive/UTKface_cropped/UTKFace'
age_labels = []
gender_labels = []
image_paths = []

image_filenames = os.listdir(BASE_DIR)
random.shuffle(image_filenames)

for image in tqdm(image_filenames):
  image_path = os.path.join(BASE_DIR, image)
  img_components = image.split('_')
  age_label = int(img_components[0])
  gender_label = int(img_components[1])

  # Append the image_path, age_label, and gender_label
  age_labels.append(age_label)
  gender_labels.append(gender_label)
  image_paths.append(image_path)
# Out:
#   0%|          | 0/23815 [00:00<?, ?it/s]

# %%
print(f'Number of age_labels: {len(age_labels)}, Number of gender_labels: {len(gender_labels)}, Number of image_paths: {len(image_paths)}')
# Out:
# Number of age_labels: 23815, Number of gender_labels: 23815, Number of image_paths: 23815

# %%
gender_mapping = {
    1: 'Female',
    0: 'Male'
}

# %%
import pandas as pd
df = pd.DataFrame()
df['image_path'], df['age'], df['gender'] = image_paths, age_labels, gender_labels
df.head(5)
# Out:
#                                           image_path  age  gender
# 0  /content/drive/MyDrive/UTKface_cropped/UTKFace...   19       1
# 1  /content/drive/MyDrive/UTKface_cropped/UTKFace...   47       0
# 2  /content/drive/MyDrive/UTKface_cropped/UTKFace...   32       0
# 3  /content/drive/MyDrive/UTKface_cropped/UTKFace...   19       1
# 4  /content/drive/MyDrive/UTKface_cropped/UTKFace...   85       1

# %%
from PIL import Image

rand_index = random.randint(0, len(image_paths))
age = df['age'][rand_index]
gender = df['gender'][rand_index]
IMG = Image.open(df['image_path'][rand_index])
plt.title(f'Age: {age} Gender: {gender_mapping[gender]}')
plt.axis('off')
plt.imshow(IMG)

# %%
 # Age distribution
 sns.distplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.countplot(df['gender'])
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(20, 20))
samples = df.iloc[0:16]

for index, sample, age, gender in samples.itertuples():
    plt.subplot(4, 4, index + 1)
    img = load_img(sample)
    img = np.array(img)
    plt.axis('off')
    plt.title(f'Age: {age} Gender: {gender_mapping[gender]}')
    plt.imshow(img)

# %%
def extract_image_features(images):
    features = list()

    for image in tqdm(images):
        img = load_img(image, grayscale=True)
        img = img.resize((128, 128), Image.ANTIALIAS)
        img = np.array(img)
        features.append(img)

    features = np.array(features)
    features = features.reshape(len(features), 128, 128, 1)
    return features

# %%
X = extract_image_features(df['image_path'])
# Out:
#   0%|          | 0/23815 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-099ffd5c3737> in <cell line: 1>()
# ----> 1 X = extract_image_features(df['image_path'])
#
# <ipython-input-10-d36fd676b83e> in extract_image_features(images)
#       3
#       4     for image in tqdm(images):
# ----> 5         img = load_img(image, grayscale=True)
#       6         img = img.resize((128, 128), Image.ANTIALIAS)
#       7         img = np.array(img)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     421             path = str(path.resolve())
#     422         with open(path, "rb") as f:
# --> 423             img = pil_image.open(io.BytesIO(f.read()))
#     424     else:
#     425         raise TypeError(
#
# KeyboardInterrupt:

# %%
X.shape

# %%
X = X / 255.0

# %%
y_gender = np.array(df['gender'])
y_age = np.array(df['age'])

# %%
input_shape = (128, 128, 1)

# %%
inputs = Input((input_shape))
conv_1 = Conv2D(32, kernel_size=(3, 3), activation='relu')(inputs)
max_1 = MaxPooling2D(pool_size=(2, 2))(conv_1)
conv_2 = Conv2D(64, kernel_size=(3, 3), activation='relu')(max_1)
max_2 = MaxPooling2D(pool_size=(2, 2))(conv_2)
conv_3 = Conv2D(128, kernel_size=(3, 3), activation='relu')(max_2)
max_3 = MaxPooling2D(pool_size=(2, 2))(conv_3)
conv_4 = Conv2D(256, kernel_size=(3, 3), activation='relu')(max_3)
max_4 = MaxPooling2D(pool_size=(2, 2))(conv_4)

flatten = Flatten()(max_4)

# fully connected layers
dense_1 = Dense(256, activation='relu')(flatten)
dense_2 = Dense(256, activation='relu')(flatten)

dropout_1 = Dropout(0.3)(dense_1)
dropout_2 = Dropout(0.3)(dense_2)

output_1 = Dense(1, activation='sigmoid', name='gender_out')(dropout_1)
output_2 = Dense(1, activation='relu', name='age_out')(dropout_2)

model = Model(inputs=[inputs], outputs=[output_1, output_2])

model.compile(loss=['binary_crossentropy', 'mae'],
              optimizer='adam', metrics=['accuracy'])

# %%
# plot the model
from tensorflow.keras.utils import plot_model
plot_model(model)

# %%
history = model.fit(x=X, y=[y_gender, y_age],
                    batch_size=32, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 595/595 [==============================] - 22s 23ms/step - loss: 15.4687 - gender_out_loss: 0.6422 - age_out_loss: 14.8265 - gender_out_accuracy: 0.6168 - age_out_accuracy: 0.0430 - val_loss: 11.5717 - val_gender_out_loss: 0.4927 - val_age_out_loss: 11.0789 - val_gender_out_accuracy: 0.7642 - val_age_out_accuracy: 0.0326
# Epoch 2/50
# 595/595 [==============================] - 12s 20ms/step - loss: 11.2262 - gender_out_loss: 0.4670 - age_out_loss: 10.7592 - gender_out_accuracy: 0.7796 - age_out_accuracy: 0.0240 - val_loss: 9.8222 - val_gender_out_loss: 0.4081 - val_age_out_loss: 9.4141 - val_gender_out_accuracy: 0.8134 - val_age_out_accuracy: 0.0149
# Epoch 3/50
# 595/595 [==============================] - 12s 20ms/step - loss: 9.8938 - gender_out_loss: 0.4062 - age_out_loss: 9.4876 - gender_out_accuracy: 0.8119 - age_out_accuracy: 0.0145 - val_loss: 9.5829 - val_gender_out_loss: 0.3670 - val_age_out_loss: 9.2159 - val_gender_out_accuracy: 0.8313 - val_age_out_accuracy: 0.0143
# Epoch 4/50
# 595/595 [==============================] - 12s 20ms/step - loss: 8.9148 - gender_out_loss: 0.3609 - age_out_loss: 8.5539 - gender_out_accuracy: 0.8343 - age_out_accuracy: 0.0104 - val_loss: 8.0821 - val_gender_out_loss: 0.3257 - val_age_out_loss: 7.7565 - val_gender_out_accuracy: 0.8507 - val_age_out_accuracy: 0.0101
# Epoch 5/50
# 595/595 [==============================] - 12s 21ms/step - loss: 8.2103 - gender_out_loss: 0.3198 - age_out_loss: 7.8906 - gender_out_accuracy: 0.8559 - age_out_accuracy: 0.0091 - val_loss: 7.6769 - val_gender_out_loss: 0.3056 - val_age_out_loss: 7.3713 - val_gender_out_accuracy: 0.8595 - val_age_out_accuracy: 0.0069
# Epoch 6/50
# 595/595 [==============================] - 12s 20ms/step - loss: 7.6809 - gender_out_loss: 0.3006 - age_out_loss: 7.3803 - gender_out_accuracy: 0.8643 - age_out_accuracy: 0.0077 - val_loss: 7.3103 - val_gender_out_loss: 0.2978 - val_age_out_loss: 7.0125 - val_gender_out_accuracy: 0.8635 - val_age_out_accuracy: 0.0065
# 595/595 [==============================] - 12s 20ms/step - loss: 3.4050 - gender_out_loss: 0.0551 - age_out_loss: 3.3499 - gender_out_accuracy: 0.9770 - age_out_accuracy: 0.0227 - val_loss: 7.1728 - val_gender_out_loss: 0.6112 - val_age_out_loss: 6.5615 - val_gender_out_accuracy: 0.8910 - val_age_out_accuracy: 0.0215
# Epoch 48/50
# 595/595 [==============================] - 12s 20ms/step - loss: 3.3452 - gender_out_loss: 0.0499 - age_out_loss: 3.2952 - gender_out_accuracy: 0.9791 - age_out_accuracy: 0.0206 - val_loss: 7.0918 - val_gender_out_loss: 0.5328 - val_age_out_loss: 6.5589 - val_gender_out_accuracy: 0.8896 - val_age_out_accuracy: 0.0246
# Epoch 49/50
# 595/595 [==============================] - 13s 21ms/step - loss: 3.3509 - gender_out_loss: 0.0500 - age_out_loss: 3.3009 - gender_out_accuracy: 0.9792 - age_out_accuracy: 0.0198 - val_loss: 7.1879 - val_gender_out_loss: 0.5490 - val_age_out_loss: 6.6389 - val_gender_out_accuracy: 0.8881 - val_age_out_accuracy: 0.0303
# Epoch 50/50
# 595/595 [==============================] - 13s 21ms/step - loss: 3.2733 - gender_out_loss: 0.0464 - age_out_loss: 3.2269 - gender_out_accuracy: 0.9793 - age_out_accuracy: 0.0252 - val_loss: 7.1811 - val_gender_out_loss: 0.5763 - val_age_out_loss: 6.6048 - val_gender_out_accuracy: 0.8858 - val_age_out_accuracy: 0.0288

# %%
model.save('/content/drive/MyDrive/UTKface_cropped/trained_model.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-823bfdfa6e87> in <cell line: 1>()
# ----> 1 model.save('/content/drive/MyDrive/UTKface_cropped/trained_model.h5')
#
# NameError: name 'model' is not defined

# %%
# plot results for gender
acc = history.history['gender_out_accuracy']
val_acc = history.history['val_gender_out_accuracy']
epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Accuracy Graph')
plt.legend()
plt.figure()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d2152b719121> in <cell line: 2>()
#       1 # plot results for gender
# ----> 2 acc = history.history['gender_out_accuracy']
#       3 val_acc = history.history['val_gender_out_accuracy']
#       4 epochs = range(len(acc))
#       5
#
# NameError: name 'history' is not defined

# %%
def get_image_features(image):
  img = load_img(image, grayscale=True)
  img = img.resize((128, 128), Image.ANTIALIAS)
  img = np.array(img)
  img = img.reshape(1, 128, 128, 1)
  img = img / 255.0
  return img

# %%
img_to_test = '/content/drive/MyDrive/UTKface_cropped/test_images/1.png'
features = get_image_features(img_to_test)
pred = model.predict(features)
gender = gender_mapping[round(pred[0][0][0])]
age = round(pred[1][0][0])

plt.title(f'Predicted Age: {age} Predicted Gender: {gender}')
plt.axis('off')
plt.imshow(np.array(load_img(img_to_test)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-fd0f13211b4b> in <cell line: 2>()
#       1 img_to_test = '/content/drive/MyDrive/UTKface_cropped/test_images/1.png'
# ----> 2 features = get_image_features(img_to_test)
#       3 pred = model.predict(features)
#       4 gender = gender_mapping[round(pred[0][0][0])]
#       5 age = round(pred[1][0][0])
#
# <ipython-input-3-1aca781eec79> in get_image_features(image)
#       1 def get_image_features(image):
# ----> 2   img = load_img(image, grayscale=True)
#       3   img = img.resize((128, 128), Image.ANTIALIAS)
#       4   img = np.array(img)
#       5   img = img.reshape(1, 128, 128, 1)
#
# NameError: name 'load_img' is not defined
